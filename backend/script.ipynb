# %%
import re

# %%
s = "the blue dog and blue cat wore blue hats"
p = re.compile(r"blue (dog|cat)")
p.sub(r'gray \1', s)
# Out:
# 'the gray dog and gray cat wore blue hats'

# %%
s = 'href="./Artificial Intelligence Development Services_files/animate.css"'
p = re.compile(r'href="(./Artificial Intelligence Development Services_files/.+)"')
print(p.sub('href="{% static \'\\1\' %}"', s))
# Out:
# href="{% static './Artificial Intelligence Development Services_files/animate.css' %}"

# %%
html = open("app/templates/Artificial Intelligence Development Services.html").read()

# %%
html
# Out:
# '{% load static %}\n\n<!DOCTYPE html>\n<!-- saved from url=(0080)https://www.oodlestechnologies.com/artificial-intelligence-development-services/ -->\n<html lang="en-US" class="js">\n  <head>\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n    <script\n      type="text/javascript"\n      async=""\n      src="./Artificial Intelligence Development Services_files/recaptcha__en_gb.js"\n      crossorigin="anonymous"\n      integrity="sha384-gUQ2nI+DjNhO23AGa5439ZOrqfsu4u3e/9SyOoghc4NkDGIjT/XssxDyvyUsk54z"\n    ></script>\n    <script\n      type="text/javascript"\n      async=""\n      defer=""\n      src="./Artificial Intelligence Development Services_files/api.js"\n    ></script>\n    <script\n      type="text/javascript"\n      async=""\n      src="./Artificial Intelligence Development Services_files/analytics.js"\n    ></script>\n    <script\n      type="text/javascript"\n      async=""\n      src="./Artificial Intelligence Development Services_files/js"\n 
# ...

# %%
p = re.compile(r'href="(./Artificial Intelligence Development Services_files/.+)"')
output = p.sub('href="{% static \'\\1\' %}"', html)

# %%
open("updated_html.html", "w").write(output)
# Out:
# 72718

# %% [markdown]
# ### update src="./Artificial...

# %%
p = re.compile(r'src="(./Artificial Intelligence Development Services_files/.+)"')
new_output = p.sub('src="{% static \'\\1\' %}"', output)

# %%
open("new_updated_html.html", "w").write(new_output)
# Out:
# 72988
